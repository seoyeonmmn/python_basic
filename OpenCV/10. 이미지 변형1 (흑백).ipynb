# %% [markdown]
# ## 10. 이미지 변형1 (흑백)
#
# #### 이미지에서 원하는 부분(원하는 정보를 담고 있는 부분)만 얻어내기 위한 전처리 과정

# %% [markdown]
# ##### *참고(review) 이미지를 흑백으로 읽음

# %%
import cv2
img = cv2.imread('img.jpg', cv2.IMREAD_GRAYSCALE)
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### 불러온 이미지를 흑백으로 변경

# %%
import cv2
img = cv2.imread('img.jpg')

dst = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow('img', img)
cv2.imshow('gray', dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)
